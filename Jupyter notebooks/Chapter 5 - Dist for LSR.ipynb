# %%
# imports and data read

import seaborn as sns
import numpy as np
from scipy import stats
import pandas 

data = pandas.read_csv('/Volumes/Windows HD/PhD/team_stability_aggregate.tsv', delimiter='\t')

# %%
# plot distributions for each metric

distplot = sns.distplot(data['Modularised Project Instability Ratio'], hist=False);
sns.plt.show()
.astype(int)

# %%
# Get the underlying data to plot in Excel

distplot = sns.distplot(data['Modularised Project Instability Ratio'], hist=False);
for i in range (0, len(distplot.get_lines()[0].get_data()[1])):
    print(distplot.get_lines()[0].get_data()[0][i], '	', distplot.get_lines()[0].get_data()[1][i])
# Out:
# -0.172282300401 	 0.00529385398054
# -0.161719330985 	 0.00898055585831
# -0.15115636157 	 0.0149312128364
# -0.140593392154 	 0.0241483860196
# -0.130030422738 	 0.0379081558077
# -0.119467453322 	 0.0577338588807
# -0.108904483907 	 0.0853170759716
# -0.0983415144908 	 0.122377136212
# -0.087778545075 	 0.170461751637
# -0.0772155756592 	 0.230706734679
# -0.0666526062435 	 0.303588759862
# -0.0560896368277 	 0.388717017429
# -0.0455266674119 	 0.484712449616
# -0.0349636979962 	 0.589213849918
# -0.0244007285804 	 0.699028611231
# -0.0138377591646 	 0.810416576351
# -0.00327478974887 	 0.919465787609
# 0.0072881796669 	 1.02249747626
# 0.0178511490827 	 1.11643095353
# 0.0284141184984 	 1.1990493085
# 0.0389770879142 	 1.26913077856
# 0.04954005733 	 1.32644090051
# 0.0601030267457 	 1.37160815053
# 0.0706659961615 	 1.40592353742
# 0.0812289655773 	 1.43110940085
# 0.091791934993 	 1.44909600123
# 0.102354904409 	 1.46183123873
# 0.112917873825 	 1.47113481589
# ...

# %%
result = scipy.stats.kstest(data['Modularised Project Instability Ratio'], cdf='norm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a079ec7a54d7> in <module>()
# ----> 1 result = scipy.stats.kstest(data['Modularised Project Instability Ratio'], cdf='norm')
#
# NameError: name 'scipy' is not defined
