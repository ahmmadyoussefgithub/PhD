# %%
import seaborn as sns
import numpy as np
from scipy import stats
import pandas 
import scipy.stats
import statsmodels.api


data = pandas.read_csv('/Volumes/Windows HD/PhD/team_size.tsv','\t')
metrics = ['CBO', 'DIT', 'LCOM', 'NOC', 'RFC', 'WMC']
# Out:
# /Users/ahmmadyoussef/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

x=data[['Class Revision Count','Project Author Count']]
variance_inflation_factor(exog=x.values, exog_idx=0)
# Out:
# 1.2174948373077685

# %%
for metric in metrics:
    model = statsmodels.api.OLS(data[metric], data[['Project Author Count', 'Class Revision Count']])
    result = model.fit()
    print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CBO   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                 2.251e+04
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):               0.00
# Time:                        23:40:35   Log-Likelihood:            -6.1668e+05
# No. Observations:              173190   AIC:                         1.233e+06
# Df Residuals:                  173188   BIC:                         1.233e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     0.5893      0.006     91.413      0.000       0.577       0.602
# Class Revision Count     0.3283      0.002    134.897      0.000       0.324       0.333
# ==============================================================================
# Omnibus:                   629628.799   Durbin-Watson:                   1.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    1187088464743.362
# Skew:                          75.599   Prob(JB):                         0.00
# Kurtosis:                   12827.947   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CBO  -->  Project Author Count    0.0
# Class Revision Count    0.0
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DIT   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                 6.784e+04
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):               0.00
# Time:                        23:40:35   Log-Likelihood:            -3.1135e+05
# No. Observations:              173190   AIC:                         6.227e+05
# Df Residuals:                  173188   BIC:                         6.227e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     0.3047      0.001    275.558      0.000       0.303       0.307
# Class Revision Count     0.0439      0.000    105.045      0.000       0.043       0.045
# ==============================================================================
# Omnibus:                    21167.950   Durbin-Watson:                   0.334
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           185359.813
# Skew:                           0.275   Prob(JB):                         0.00
# Kurtosis:                       8.038   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# DIT  -->  Project Author Count    0.0
# Class Revision Count    0.0
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   LCOM   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.428
# Method:                 Least Squares   F-statistic:                 6.487e+04
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):               0.00
# Time:                        23:40:35   Log-Likelihood:            -9.0667e+05
# No. Observations:              173190   AIC:                         1.813e+06
# Df Residuals:                  173188   BIC:                         1.813e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     7.7390      0.034    225.018      0.000       7.672       7.806
# Class Revision Count     2.0750      0.013    159.801      0.000       2.050       2.100
# ==============================================================================
# Omnibus:                     4111.362   Durbin-Watson:                   0.537
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4219.424
# Skew:                          -0.363   Prob(JB):                         0.00
# Kurtosis:                       2.763   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# LCOM  -->  Project Author Count    0.0
# Class Revision Count    0.0
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    NOC   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     196.4
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):           6.44e-86
# Time:                        23:40:35   Log-Likelihood:            -5.1407e+05
# No. Observations:              173190   AIC:                         1.028e+06
# Df Residuals:                  173188   BIC:                         1.028e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     0.0536      0.004     15.036      0.000       0.047       0.061
# Class Revision Count     0.0072      0.001      5.345      0.000       0.005       0.010
# ==============================================================================
# Omnibus:                   834968.758   Durbin-Watson:                   1.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   13857584026359.998
# Skew:                         190.209   Prob(JB):                         0.00
# Kurtosis:                   43822.923   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# NOC  -->  Project Author Count    4.576865e-51
# Class Revision Count    9.040623e-08
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RFC   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                 1.165e+04
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):               0.00
# Time:                        23:40:35   Log-Likelihood:            -8.4868e+05
# No. Observations:              173190   AIC:                         1.697e+06
# Df Residuals:                  173188   BIC:                         1.697e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     2.0575      0.025     83.616      0.000       2.009       2.106
# Class Revision Count     0.7470      0.009     80.412      0.000       0.729       0.765
# ==============================================================================
# Omnibus:                   630655.132   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    1143009688602.754
# Skew:                          76.011   Prob(JB):                         0.00
# Kurtosis:                   12587.544   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RFC  -->  Project Author Count    0.0
# Class Revision Count    0.0
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WMC   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                 1.003e+04
# Date:                Tue, 08 Aug 2017   Prob (F-statistic):               0.00
# Time:                        23:40:35   Log-Likelihood:            -8.0577e+05
# No. Observations:              173190   AIC:                         1.612e+06
# Df Residuals:                  173188   BIC:                         1.612e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Project Author Count     1.1423      0.019     59.472      0.000       1.105       1.180
# Class Revision Count     0.6624      0.007     91.349      0.000       0.648       0.677
# ==============================================================================
# Omnibus:                   779486.631   Durbin-Watson:                   1.528
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    7885973863754.777
# Skew:                         150.190   Prob(JB):                         0.00
# Kurtosis:                   33059.278   Cond. No.                         3.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# WMC  -->  Project Author Count    0.0
# Class Revision Count    0.0
# dtype: float64
